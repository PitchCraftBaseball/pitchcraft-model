# %%
import pandas as pd
pd.set_option('display.max_columns', 1000)
# pd.set_option('display.max_rows', 1000)

# %%
data = pd.read_csv('train_data2425.csv')

# %%
data.head(20)
# Out:
#    pitch_type   game_date  batter  pitcher      description  zone stand  \
# 0          FF  2023-03-30  680757   622491             ball  11.0     L
# 1          SI  2023-03-30  680757   622491             ball  13.0     L
# 2          FF  2023-03-30  680757   622491             ball  12.0     L
# 3          FF  2023-03-30  680757   622491    called_strike   1.0     L
# 4          SI  2023-03-30  680757   622491    called_strike  11.0     L
# 5          SI  2023-03-30  642708   622491             foul   8.0     R
# 6          SL  2023-03-30  642708   622491  swinging_strike   2.0     R
# 7          SI  2023-03-30  608070   622491    called_strike   9.0     L
# 8          FF  2023-03-30  608070   622491    called_strike  11.0     L
# 9          FF  2023-03-30  677594   669456             ball  14.0     R
# 10         FF  2023-03-30  677594   669456             foul   3.0     R
# 11         FC  2023-03-30  677594   669456  swinging_strike   6.0     R
# ...
